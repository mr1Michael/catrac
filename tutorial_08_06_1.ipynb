# %% [markdown]
# # 1 Working with better datatypes
# ## 1.1 Lists and arrays

# %% [markdown]
# ## 1.2 Dictionaries

# %% [markdown]
# ## 1.3 Strings and Characters

# %% [markdown]
# # 1.4 Dataframes
