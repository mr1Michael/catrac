# %%
name_test = "Michael"
age_test = 37


def print_person(name, age):
    print(name)
    print(age)

# %%
print_person("Rachel", "22" )
# Out:
# Rachel
# 22

# %%
def guess_weight(person):
    if person == "Rachel":
        return 59
    if person == "Michael":
        return 90
    if person == "Cat":
        return 58

# %%
weight = guess_weight("Rachel")

# %%
print(weight)
# Out:
# 59

# %%
print(guess_weight("Michael"))
# Out:
# 90

# %%
import pandas as pd

# %%
cats = pd.read_csv("categories.csv", delimiter=";")

# %%
cats.head()
# Out:
#        Brand               cat1              cat2                cat3
# 0   ENERGADE  Sports and Energy    Cold Beverages           Beverages
# 1  LADYSMITH             Cheese             Dairy  Chilled and Frozen
# 2      DUREX             Safety  House and Garden        Evening wear

# %%
cats.columns
# Out:
# Index(['Brand', ' cat1', ' cat2', 'cat3'], dtype='str')

# %%
for brands in cats["Brand"]:
    print(brands)
# Out:
# ENERGADE
# LADYSMITH
# DUREX

# %%
for headings in cats.columns:


    print(cats.iloc[0][headings])
# Out:
# ENERGADE
# Sports and Energy
# Cold Beverages
# Beverages

# %%
cats.iloc[0].to_dict()
# Out:
# {'Brand': 'ENERGADE',
#  ' cat1': 'Sports and Energy',
#  ' cat2': 'Cold Beverages',
#  'cat3': 'Beverages'}

# %%
tup = (1,2,3,4,5,6)

# %%
tup[:3]
# Out:
# (1, 2, 3)

# %%
tup[3:]
# Out:
# (4, 5, 6)

# %%
rach_tuple = (1,1, 3)

# %%
rach_tuple
# Out:
# (1, 1, 3)

# %%
rach_list = [1,1,3]

# %%
rach_list
# Out:
# [1, 1, 3]

# %%
rach_set = {1,1,3}

# %%
rach_set
# Out:
# {1, 3, 9}

# %%
rach_set.add(9)

# %%
rach_set.add(9)

# %%
rach_set
# Out:
# {1, 3, 9}
