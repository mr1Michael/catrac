# %%
list_name = [1,  9, 3.01]
print(list_name)
# Out:
# [1, 9, 3.01]

# %%
for items in list_name:
    if items > 4:
        print(items)
# Out:
# 9

# %%
list2d = [[1,    9],
          ["me", "you"],
          [0.01, 0.09]]
print(list2d[1][-1] + list2d[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 list2d = [[1,    9],
#       2           ["me", "you"],
#       3           [0.01, 0.09]]
# ----> 4 print(list2d[1][-1] + list2d[0][1])
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = list2d
type(x)
# Out:
# list

# %%
mixed_list = [45, 110, list_name, "yoda", "trin"]
# print(mixed_list)

for items in mixed_list:
    if type(items) == str:
        print(items)
# Out:
# yoda
# trin

# %%
list2d
# Out:
# [[0.01, 0.09], ['me', 'you'], [1, 9]]

# %%
dict_sal = {"mike": 15000, "rach": 1500, "cat": -20}

print(dict_sal["cat"])
# Out:
# -20

# %%
import guessing_game

guessing_game.spell_my_name()
# Out:
# <class 'function'>
# m
# i
# k
# e

# %%
name = "Cattherrinnne"

# %%
count = 0
for letter in name:
    if letter == "n":
        count += 1

print(count)
# Out:
# 3

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [2, 4, 1])
plt.xlabel("x")
plt.ylabel("y")
plt.title("Example")
plt.show()
